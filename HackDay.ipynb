# %% [markdown]
# # What was given??

# %%
from IPython.display import Image
Image(filename='test.jpg', width=800,height=100)

# %% [markdown]
# # Challenge
#
# * Extracting the products in the shelf
# * Extracting the information from the price tag

# %% [markdown]
# ## Extracting the products from the shelf
#
# * Template Matching = Done
# * Deep Net Features matching = Next Steps
#
#
# ## Extracting the information from the price tag
#
# * Template Matching = Done
# * Deep Net Features matching = Next Steps

# %% [markdown]
# # Demo

# %%
from ipywidgets import interact, interactive, fixed, widgets
